# %% [markdown]
# Simple GAN

# %%
import torch
import torch.nn as nn

# %%
#Generator

class Generator(torch.nn):

    def __init__(self,noise_dim=100,img_channel=3):
        super().__init__()

        self.model = nn.Sequential(

            nn.Linear(noise_dim,256),
            nn.ReLU(True),
            nn.Linear(256,512),
            nn.ReLU(True),
            nn.Linear(512,64*64*img_channel),
            nn.Tanh()
        )

    def forward(self,inp_image):
        pass
